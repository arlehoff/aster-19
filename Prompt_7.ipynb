# %% [markdown]
# Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# create a numpy array x ranging from [0,1] in 100 steps

# %%
x = np.linspace(0, 1, 100)

# %% [markdown]
# define a function that returns exp(x)

# %%
def exp_function(x):
    return np.exp(x)

# %% [markdown]
# use the function to set y = exp(x)

# %%
y = exp_function(x)

# %% [markdown]
# plot x vs. y and label the x-axis as “Time [milliseconds]” and the y-axis as “Awesomeness”

# %%
plt.plot(x, y)
plt.xlabel('Time [milliseconds]')
plt.ylabel('Awesomeness')
plt.title('Exponential Growth of Awesomeness')
# Out:
# Text(0.5, 1.0, 'Exponential Growth of Awesomeness')

# %% [markdown]
# Save the figure as a pdf

# %%
plt.savefig('awesome_plot.pdf')
plt.show()
